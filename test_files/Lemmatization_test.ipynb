# %%
import spacy
import pandas as pd

# %%
ghelms_data = "/Users/gustavhelms/Documents/Cognitive Science/5_semester/Bachelor/political_polarization/Folketinget-Scraping/data/folketinget_2019_2021_raw.csv"

df = pd.read_csv(ghelms_data)

# %%
df.head(5)
# Out:
#                    Title                  id  Samling   Nr  \
# 0                 Adsbøl  20201_M108_referat    20201  108
# 1                 Adsbøl  20201_M108_referat    20201  108
# 2                 Ahlers  20201_M114_referat    20201  114
# 3  Aki-Matilda Høegh-Dam  20201_M110_referat    20201  110
# 4  Aki-Matilda Høegh-Dam  20201_M110_referat    20201  110
#
#                                              Titel        Dato  speaker_id  \
# 0   Referat af møde 108 den 4. maj, 2021 kl. 13.00  04-05-2021       42762
# 1   Referat af møde 108 den 4. maj, 2021 kl. 13.00  04-05-2021       42788
# 2  Referat af møde 114 den 11. maj, 2021 kl. 14.30  11-05-2021       45782
# 3   Referat af møde 110 den 6. maj, 2021 kl. 10.00  06-05-2021       44397
# 4   Referat af møde 110 den 6. maj, 2021 kl. 10.00  06-05-2021       44413
#
#                                                 text                  Date  \
# 0  der fik i lige reddet mig . ja, det var en spæ...  2021-05-04T20:12:00Z
# 1  jeg vil så gerne blive lidt længere . men vi g...  2021-05-04T20:24:00Z
# 2  hvis hr. tommy ahlers var gået ind i forhandli...  2021-05-11T17:05:00Z
# 3  vi behandler i dag et beslutningsforslag, hvor...  2021-05-06T14:32:00Z
# 4  tak. jeg finder det interessant, at df i bemær...  2021-05-06T14:47:00Z
#
#    doc_id                   Name  Year Period             Parti
# 0   36438          Karina Adsbøl  2021  2019-  Dansk Folkeparti
# 1   36466          Karina Adsbøl  2021  2019-  Dansk Folkeparti
# 2   39795           Tommy Ahlers  2021  2019-           Venstre
# 3   38255  Aki-Matilda Høegh-Dam  2021  2019-            Siumut
# 4   38274  Aki-Matilda Høegh-Dam  2021  2019-            Siumut

# %%
nlp = spacy.load("da_core_news_sm", disable = ["ner", "parser"])

# %%
nlp.components
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7fbcb8b6f310>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x7fbc95191b80>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7fbc9517f580>),
#  ('senter', <spacy.pipeline.senter.SentenceRecognizer at 0x7fbc951914f0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7fbcbaf4b140>),
#  ('lemmatizer', <spacy.pipeline.lemmatizer.Lemmatizer at 0x7fbcbb22b880>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7fbcce9f8f40>)]

# %%
nlp.disabled
# Out:
# ['parser', 'senter', 'ner']

# %%
sentence = df["text"][0]
doc = nlp(sentence)

" ".join([token.lemma_ for token in doc])
# Out:
# ': deres majestæt og kongelig højhed . gennem 170 år være det kun krig og corona , der have kunne forstyrre frihed og folkestyre i danmark . jeg have være mede til folketing åbning 40 gang kun overgå af hendes majestæt og det være 10. gang , jeg åbne folketingsår , men aldrig unde sådan omstændighed . normal demokratisk debattere og beslutningsproces have være sætte til side . regering have mede folketing accept tag over i hidtil uset grad . min ønske til det ny år være , at vi lære at træffe hurtig beslutning uden demokratisk underskud , uden at det gå ud over logik og forudsigelighed , og mede klarhed over , hvad der være sagkundskab , og hvad der være politisk valg . vi have her i sal tag vores eg medicin og følge vores egn restriktion . vi have improvisere , vandre rund i vandrehal og være gå ud og ind tie ad gang for ikke at være for mangen i sal , nå vi skulle stemme . og heller ikke i dag være vi uanfægtet af pandemien , men vi skulle møde den først tirsdag i oktober : det sige grundlov . den kræve , at vi møde og start arbejde den først tirsdag i oktober og påhøre statsminister redegørelse om og jeg citer rige almindelig stilling og de af regering påtænke foranstaltning « . ifølge folketing forretningsorden være det jeg , der som aldersformand , det ville sige ikke den gammel , men den lang sidde , skulle åbne ting og få det sætte . det ville sige , at jeg skulle lede valg af præsidium og tingsekretærer . : til først næstformand have venstre gruppe udpege fru karen ellemann . efter fælles forståelse mellem dansk folkeparti og radikal venstre , som have lige mangen medlem , være udpegning af and og tredje næstformand ske uden lodtrækning . til and næstformand have dansk folkeparti gruppe udpege fru pia kjærsgaard . til tredje næstformand have radikal venstre gruppe udpege hr. jens rohde . og til fjerde næstformand have socialistisk folkeparti gruppe udpege fru trine torp . det næste punkt på dagsorden være : 3 valg af 4 tingsekretærer . dagsorden 1 valg af formand . 2 valg af 4 næstformand . 3 valg af 4 tingsekretærer . 4 statsminister redegørelse i henholde til grundlov § 38 . det næste punkt på dagsorden være : 2 valg af 4 næstformand . : til formand have samtlige parti indstille hr. henrik dam kristensen . hvis ingen begære afstemning , ville jeg betragte hr. henrik dam kristensen som vælge . han være vælge . : til tingsekretærer være i henholde til de indgå valgforbund og gruppe indstilling vælge følge medlem : fru annette lind s , hr. christian juhl el , hr. erling bonnesen v og hr. bent bøgsted df . hermed være ting sætte , og jeg skulle bed formand om at indtage sin formandsplads .'

# %%
/Users/gustavhelms/Documents/Cognitive Science/5_semester/Bachelor/political_polarization/Folketinget-Scraping/data/folketinget_2019_2021_raw.csv

# %%
df.head(5)
# Out:
#                  Title                id  Samling  Nr  \
# 0       Bertel Haarder  20201_M1_referat    20201   1
# 1         Torsten Gejl  20201_M3_referat    20201   3
# 2      Jesper Petersen  20201_M3_referat    20201   3
# 3    Sikandar Siddique  20201_M2_referat    20201   2
# 4  Lars Boje Mathiesen  20201_M4_referat    20201   4
#
#                                                Titel        Dato  speaker_id  \
# 0   Referat af møde 1 den 6. oktober, 2020 kl. 12.00  06-10-2020           0
# 1    Referat af møde 3 den 8. oktober, 2020 kl. 9.00  08-10-2020        1008
# 2    Referat af møde 3 den 8. oktober, 2020 kl. 9.00  08-10-2020         189
# 3   Referat af møde 2 den 7. oktober, 2020 kl. 13.00  07-10-2020          18
# 4  Referat af møde 4 den 20. oktober, 2020 kl. 13.00  20-10-2020        1900
#
#                                                 text                  Date  \
# 0  : deres majestæt og kongelige højheder. gennem...  2020-10-06T11:58:00Z
# 1  : ja, man må jo presse på, og man må komme med...  2020-10-08T19:25:00Z
# 2  : jeg tror ikke, at der er lande, der har en m...  2020-10-08T09:23:00Z
# 3  : det første punkt på dagsordenen er: 1 valg a...  2020-10-07T13:04:00Z
# 4  : jeg synes faktisk, der er kommet op til fler...  2020-10-20T19:59:00Z
#
#    doc_id                 Name  Year               Parti Period  .groups  \
# 0       1       Bertel Haarder  2020             Venstre  2019-        1
# 1      10         Torsten Gejl  2020        Alternativet  2019-        1
# 2    1000      Jesper Petersen  2020   Socialdemokratiet  2019-        1
# 3    1001    Sikandar Siddique  2020        Alternativet  2019-        1
# 4    1002  Lars Boje Mathiesen  2020  x - Nye Borgerlige  2019-        1
#
#                                           lemmatized
# 0  : deres majestæt og kongelig højhed . gennem 1...
# 1  : ja , man måtte jo presse på , og man måtte k...
# 2  : jeg tro ikke , at der være land , der have e...
# 3  : det først punkt på dagsorden være : 1 valg a...
# 4  : jeg syne faktisk , der være komme oppe til f...

# %%
import spacy
import pandas as pd

# Loading in the data
file_path_gustav = "/Users/gustavhelms/Documents/Cognitive Science/5_semester/Bachelor/political_polarization/Folketinget-Scraping/data/folketinget_2019_2021_raw.csv"
df = pd.read_csv(file_path_gustav)

# Loading the model, disabling all modules that are not relevant for the lemmatization
nlp = spacy.load("da_core_news_sm", disable = ["ner", "parser"])

# lemmatization loop
lemmatized = []
for speech in df["text"]:
    doc = nlp(speech)
    lemmatized.append(" ".join([token.lemma_ for token in doc]))

# Appending the lemmatized text to the data frame
df["lemmatized"] = lemmatized

df.to_csv("folketinget_2019_2021_lemmatized.csv",
                sep=";", index=False)
